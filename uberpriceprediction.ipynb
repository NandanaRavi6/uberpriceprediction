# %%
#LYFT and uber price prediction
#importing libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
#reading csv files
rides_df=pd.read_csv('f:\cab_rides.csv')

# %%
weather_df=pd.read_csv('f:\weather.csv')

# %%
rides_df
# Out:
#         distance cab_type    time_stamp    destination            source  \
# 0           0.44     Lyft  1.544950e+12  North Station  Haymarket Square
# 1           0.44     Lyft  1.543280e+12  North Station  Haymarket Square
# 2           0.44     Lyft  1.543370e+12  North Station  Haymarket Square
# 3           0.44     Lyft  1.543550e+12  North Station  Haymarket Square
# 4           0.44     Lyft  1.543460e+12  North Station  Haymarket Square
# ...          ...      ...           ...            ...               ...
# 693066      1.00     Uber  1.543710e+12      North End          West End
# 693067      1.00     Uber  1.543710e+12      North End          West End
# 693068      1.00     Uber  1.543710e+12      North End          West End
# 693069      1.00     Uber  1.543710e+12      North End          West End
# 693070      1.00     Uber  1.543710e+12      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
rides_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          693071 non-null  float64
#  1   cab_type          693071 non-null  object
#  2   time_stamp        693071 non-null  float64
#  3   destination       693071 non-null  object
#  4   source            693071 non-null  object
#  5   price             637976 non-null  float64
#  6   surge_multiplier  693071 non-null  float64
#  7   id                693071 non-null  object
#  8   product_id        693071 non-null  object
#  9   name              693071 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 52.9+ MB

# %%
weather_df
# Out:
#        temp                 location  clouds  pressure    rain  time_stamp  \
# 0     42.42                 Back Bay    1.00   1012.14  0.1228  1545003901
# 1     42.43              Beacon Hill    1.00   1012.15  0.1846  1545003901
# 2     42.50        Boston University    1.00   1012.15  0.1089  1545003901
# 3     42.11                   Fenway    1.00   1012.13  0.0969  1545003901
# 4     43.13       Financial District    1.00   1012.14  0.1786  1545003901
# ...     ...                      ...     ...       ...     ...         ...
# 6271  44.72            North Station    0.89   1000.69     NaN  1543819974
# 6272  44.85  Northeastern University    0.88   1000.71     NaN  1543819974
# 6273  44.82            South Station    0.89   1000.70     NaN  1543819974
# 6274  44.78         Theatre District    0.89   1000.70     NaN  1543819974
# 6275  44.69                 West End    0.89   1000.70     NaN  1543819974
#
#       humidity   wind
# 0         0.77  11.25
# ...

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6276 entries, 0 to 6275
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   temp        6276 non-null   float64
#  1   location    6276 non-null   object
#  2   clouds      6276 non-null   float64
#  3   pressure    6276 non-null   float64
#  4   rain        894 non-null    float64
#  5   time_stamp  6276 non-null   int64
#  6   humidity    6276 non-null   float64
#  7   wind        6276 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 392.4+ KB

# %%
#cleaning the data
#to check null values in ride dataset
rides_df.isna().sum()
# Out:
# distance                0
# cab_type                0
# time_stamp              0
# destination             0
# source                  0
# price               55095
# surge_multiplier        0
# id                      0
# product_id              0
# name                    0
# dtype: int64

# %%
#dropping null values in dataset row wise
rides_df=rides_df.dropna(axis=0).reset_index(drop=True)

# %%
rides_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637976 entries, 0 to 637975
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          637976 non-null  float64
#  1   cab_type          637976 non-null  object
#  2   time_stamp        637976 non-null  float64
#  3   destination       637976 non-null  object
#  4   source            637976 non-null  object
#  5   price             637976 non-null  float64
#  6   surge_multiplier  637976 non-null  float64
#  7   id                637976 non-null  object
#  8   product_id        637976 non-null  object
#  9   name              637976 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 48.7+ MB

# %%
#checking null values in weather data
weather_df.isna().sum()
# Out:
# temp             0
# location         0
# clouds           0
# pressure         0
# rain          5382
# time_stamp       0
# humidity         0
# wind             0
# dtype: int64

# %%
#filling up null value in weather dataset
weather_df=weather_df.fillna(0)

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6276 entries, 0 to 6275
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   temp        6276 non-null   float64
#  1   location    6276 non-null   object
#  2   clouds      6276 non-null   float64
#  3   pressure    6276 non-null   float64
#  4   rain        6276 non-null   float64
#  5   time_stamp  6276 non-null   int64
#  6   humidity    6276 non-null   float64
#  7   wind        6276 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 392.4+ KB

# %%
weather_df
# Out:
#        temp                 location  clouds  pressure    rain  time_stamp  \
# 0     42.42                 Back Bay    1.00   1012.14  0.1228  1545003901
# 1     42.43              Beacon Hill    1.00   1012.15  0.1846  1545003901
# 2     42.50        Boston University    1.00   1012.15  0.1089  1545003901
# 3     42.11                   Fenway    1.00   1012.13  0.0969  1545003901
# 4     43.13       Financial District    1.00   1012.14  0.1786  1545003901
# ...     ...                      ...     ...       ...     ...         ...
# 6271  44.72            North Station    0.89   1000.69  0.0000  1543819974
# 6272  44.85  Northeastern University    0.88   1000.71  0.0000  1543819974
# 6273  44.82            South Station    0.89   1000.70  0.0000  1543819974
# 6274  44.78         Theatre District    0.89   1000.70  0.0000  1543819974
# 6275  44.69                 West End    0.89   1000.70  0.0000  1543819974
#
#       humidity   wind
# 0         0.77  11.25
# ...

# %%
weather_df.groupby('location').mean()
# Out:
#                               temp    clouds     pressure      rain  \
# location
# Back Bay                 39.082122  0.678432  1008.447820  0.007925
# Beacon Hill              39.047285  0.677801  1008.448356  0.008297
# Boston University        39.047744  0.679235  1008.459254  0.007738
# Fenway                   38.964379  0.679866  1008.453289  0.007343
# Financial District       39.410822  0.676730  1008.435793  0.008563
# Haymarket Square         39.067897  0.676711  1008.445239  0.008660
# North End                39.090841  0.676730  1008.441912  0.008644
# North Station            39.035315  0.676998  1008.442811  0.008649
# Northeastern University  38.975086  0.678317  1008.444168  0.007358
# South Station            39.394092  0.677495  1008.438031  0.008310
# Theatre District         38.986711  0.677763  1008.444742  0.008405
# West End                 38.983403  0.677247  1008.441090  0.008657
#
#                            time_stamp  humidity      wind
# location
# ...

# %%
#weather_df.shape
# Out:
# (6276, 8)

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6276 entries, 0 to 6275
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   temp        6276 non-null   float64
#  1   location    6276 non-null   object
#  2   clouds      6276 non-null   float64
#  3   pressure    6276 non-null   float64
#  4   rain        6276 non-null   float64
#  5   time_stamp  6276 non-null   int64
#  6   humidity    6276 non-null   float64
#  7   wind        6276 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 392.4+ KB

# %%
#data manipulation
avg_weather_df=weather_df.groupby('location').mean().reset_index(drop=False)

# %%
avg_weather_df
# Out:
#                    location       temp    clouds     pressure      rain  \
# 0                  Back Bay  39.082122  0.678432  1008.447820  0.007925
# 1               Beacon Hill  39.047285  0.677801  1008.448356  0.008297
# 2         Boston University  39.047744  0.679235  1008.459254  0.007738
# 3                    Fenway  38.964379  0.679866  1008.453289  0.007343
# 4        Financial District  39.410822  0.676730  1008.435793  0.008563
# 5          Haymarket Square  39.067897  0.676711  1008.445239  0.008660
# 6                 North End  39.090841  0.676730  1008.441912  0.008644
# 7             North Station  39.035315  0.676998  1008.442811  0.008649
# 8   Northeastern University  38.975086  0.678317  1008.444168  0.007358
# 9             South Station  39.394092  0.677495  1008.438031  0.008310
# 10         Theatre District  38.986711  0.677763  1008.444742  0.008405
# 11                 West End  38.983403  0.677247  1008.441090  0.008657
#
# ...

# %%
avg_weather_df=avg_weather_df.drop('time_stamp',axis=1)

# %%
avg_weather_df
# Out:
#                    location       temp    clouds     pressure      rain  \
# 0                  Back Bay  39.082122  0.678432  1008.447820  0.007925
# 1               Beacon Hill  39.047285  0.677801  1008.448356  0.008297
# 2         Boston University  39.047744  0.679235  1008.459254  0.007738
# 3                    Fenway  38.964379  0.679866  1008.453289  0.007343
# 4        Financial District  39.410822  0.676730  1008.435793  0.008563
# 5          Haymarket Square  39.067897  0.676711  1008.445239  0.008660
# 6                 North End  39.090841  0.676730  1008.441912  0.008644
# 7             North Station  39.035315  0.676998  1008.442811  0.008649
# 8   Northeastern University  38.975086  0.678317  1008.444168  0.007358
# 9             South Station  39.394092  0.677495  1008.438031  0.008310
# 10         Theatre District  38.986711  0.677763  1008.444742  0.008405
# 11                 West End  38.983403  0.677247  1008.441090  0.008657
#
#     humidity      wind
# ...

# %%
#merging the dataframes
rides_df
# Out:
#         distance cab_type    time_stamp    destination            source  \
# 0           0.44     Lyft  1.544950e+12  North Station  Haymarket Square
# 1           0.44     Lyft  1.543280e+12  North Station  Haymarket Square
# 2           0.44     Lyft  1.543370e+12  North Station  Haymarket Square
# 3           0.44     Lyft  1.543550e+12  North Station  Haymarket Square
# 4           0.44     Lyft  1.543460e+12  North Station  Haymarket Square
# ...          ...      ...           ...            ...               ...
# 637971      1.00     Uber  1.543710e+12      North End          West End
# 637972      1.00     Uber  1.543710e+12      North End          West End
# 637973      1.00     Uber  1.543710e+12      North End          West End
# 637974      1.00     Uber  1.543710e+12      North End          West End
# 637975      1.00     Uber  1.543710e+12      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
source_weather_df = avg_weather_df.rename(columns = {
   
        'location' : 'source',
        'temp' : 'source_temp',
        'çlouds' : 'source_clouds',
        'pressure' : 'source_pressure',
        'rain' : 'source_rain',
        'humidity' : 'source_humidity',
        'wind' : 'source_wind'
}
                                          
)

# %%
source_weather_df
# Out:
#                      source  source_temp    clouds  source_pressure  \
# 0                  Back Bay    39.082122  0.678432      1008.447820
# 1               Beacon Hill    39.047285  0.677801      1008.448356
# 2         Boston University    39.047744  0.679235      1008.459254
# 3                    Fenway    38.964379  0.679866      1008.453289
# 4        Financial District    39.410822  0.676730      1008.435793
# 5          Haymarket Square    39.067897  0.676711      1008.445239
# 6                 North End    39.090841  0.676730      1008.441912
# 7             North Station    39.035315  0.676998      1008.442811
# 8   Northeastern University    38.975086  0.678317      1008.444168
# 9             South Station    39.394092  0.677495      1008.438031
# 10         Theatre District    38.986711  0.677763      1008.444742
# 11                 West End    38.983403  0.677247      1008.441090
#
#     source_rain  source_humidity  source_wind
# ...

# %%
destination_weather_df = avg_weather_df.rename(columns = {
   
        'location' : 'destination',
        'temp' : 'destination_temp',
        'çlouds' : 'destination_clouds',
        'pressure' : 'destination_pressure',
        'rain' : 'destination_rain',
        'humidity' : 'destination_humidity',
        'wind' : 'destination_wind'
}
)

# %%
destination_weather_df
# Out:
#                 destination  destination_temp    clouds  destination_pressure  \
# 0                  Back Bay         39.082122  0.678432           1008.447820
# 1               Beacon Hill         39.047285  0.677801           1008.448356
# 2         Boston University         39.047744  0.679235           1008.459254
# 3                    Fenway         38.964379  0.679866           1008.453289
# 4        Financial District         39.410822  0.676730           1008.435793
# 5          Haymarket Square         39.067897  0.676711           1008.445239
# 6                 North End         39.090841  0.676730           1008.441912
# 7             North Station         39.035315  0.676998           1008.442811
# 8   Northeastern University         38.975086  0.678317           1008.444168
# 9             South Station         39.394092  0.677495           1008.438031
# 10         Theatre District         38.986711  0.677763           1008.444742
# ...

# %%
data = rides_df\
        .merge(source_weather_df, on='source')\
    .merge(destination_weather_df, on='destination')

# %%
data
# Out:
#         distance cab_type    time_stamp       destination              source  \
# 0           0.44     Lyft  1.544950e+12     North Station    Haymarket Square
# 1           0.44     Lyft  1.543280e+12     North Station    Haymarket Square
# 2           0.44     Lyft  1.543370e+12     North Station    Haymarket Square
# 3           0.44     Lyft  1.543550e+12     North Station    Haymarket Square
# 4           0.44     Lyft  1.543460e+12     North Station    Haymarket Square
# ...          ...      ...           ...               ...                 ...
# 637971      0.99     Lyft  1.543220e+12  Haymarket Square  Financial District
# 637972      0.99     Lyft  1.543220e+12  Haymarket Square  Financial District
# 637973      0.99     Lyft  1.543470e+12  Haymarket Square  Financial District
# 637974      0.99     Lyft  1.544760e+12  Haymarket Square  Financial District
# 637975      0.99     Lyft  1.544760e+12  Haymarket Square  Financial District
#
# ...

# %%
def onehot_encode(df, column, prefix):
    df = df.copy()
    dummies = pd.get_dummies(df[column], prefix=prefix)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column, axis=1)
    return df

# %%
#data preprocessing
def preprocess_inputs(df):
    df = df.copy()
    
    #dropping unneeded columns
    df = df.drop('id', axis=1)
    
    #binary encode cab_type column
    df['cab_type'] = df['cab_type'].replace({'Lyft': 0, 'Uber': 1})
    
    #onehot_encode remaining categorical
    for column,prefix in [('destination', "desti"), ('source', "src"), ('product_id', "pid"),('name',"nm")]:
        df=onehot_encode(df, column=column, prefix=prefix)
        
    #split  df into x and y
    Y = df['price']
    X = df.drop('price', axis=1)
    
    #train_test split
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.7, shuffle=True, random_state=1)
    
    #scale x
    scaler = StandardScaler()
    scaler.fit(X_train)
    
    X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)
    
    return X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = preprocess_inputs(data)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 X_train, X_test, Y_train, Y_test = preprocess_inputs(data)
#
# Input In [28], in preprocess_inputs(df)
#       2 def preprocess_inputs(df):
# ----> 3     df = df.copy()
#       5     #dropping unneeded columns
#       6     df = df.drop('id', axis=1)
#
# File F:\python\lib\site-packages\pandas\core\generic.py:6032, in NDFrame.copy(self, deep)
#    5926 @final
#    5927 def copy(self: NDFrameT, deep: bool_t = True) -> NDFrameT:
#    5928     """
#    5929     Make a copy of this object's indices and data.
#    5930
#    (...)
#    6030     dtype: object
#    6031     """
# -> 6032     data = self._mgr.copy(deep=deep)
#    6033     self._clear_item_cache()
#    6034     return self._constructor(data).__finalize__(self, method="copy")
#
# ...

# %%
X_train.var()
# Out:
# distance            1.287267e+00
# cab_type            2.496761e-01
# time_stamp          4.751374e+17
# surge_multiplier    9.099371e-03
# source_temp         2.127758e-02
#                         ...
# nm_Shared           7.370316e-02
# nm_UberPool         7.896140e-02
# nm_UberX            7.896302e-02
# nm_UberXL           7.888684e-02
# nm_WAV              7.872146e-02
# Length: 64, dtype: float64

# %%
Y_train
# Out:
# 564759     7.0
# 547094    27.5
# 447791     9.0
# 417124    14.0
# 215864    11.5
#           ...
# 371403    10.5
# 491263    27.5
# 470924    18.5
# 491755    16.5
# 128037    23.0
# Name: price, Length: 510380, dtype: float64

# %%
#training

model = LinearRegression()
model.fit(X_train, Y_train)

print("test R^2 score: {:.5f}".format(model.score(X_test, Y_test)))
# Out:
# test R^2 score: 0.92801
